# %%
marks = []

for i in range(5):
    mark = int(input(f"Enter marks of Subject {i+1}: "))
    marks.append(mark)

total = sum(marks)
average = total / len(marks)

print("\nTotal Marks:", total)
print("Average:", average)

if average >= 90:
    grade = "A+"
elif average >= 80:
    grade = "A"
elif average >= 70:
    grade = "B"
elif average >= 60:
    grade = "C"
else:
    grade = "Fail"

print("Grade:", grade)
# Out:
# Enter marks of Subject 1:  80
# Enter marks of Subject 2:  80
# Enter marks of Subject 3:  80
# Enter marks of Subject 4:  80
# Enter marks of Subject 5:  80
# Total Marks: 400
# Average: 80.0
# Grade: A

# %%
password = input("Enter Password: ")

if len(password) < 8:
    print("Weak Password")

elif password.isalpha():
    print("Add Numbers")

elif password.isdigit():
    print("Add Letters")

else:
    print("Strong Password")
# Out:
# Enter Password:  ravi@12345
# Strong Password

# %%
balance = 50000

while True:

    print("\n1.Check Balance")
    print("2.Deposit")
    print("3.Withdraw")
    print("4.Exit")

    choice = int(input("Choose: "))

    if choice == 1:
        print("Balance:", balance)

    elif choice == 2:
        amount = int(input("Deposit Amount: "))
        balance += amount
        print("Money Deposited")

    elif choice == 3:
        amount = int(input("Withdraw Amount: "))

        if amount <= balance:
            balance -= amount
            print("Collect Cash")
        else:
            print("Insufficient Balance")

    elif choice == 4:
        break

    else:
        print("Invalid Choice")
# Out:
# 1.Check Balance
# 2.Deposit
# 3.Withdraw
# 4.Exit
# Choose:  4

# %%
sentence = input("Enter Sentence: ")

words = sentence.split()

print("Total Words:", len(words))

for word in words:
    print(word)
# Out:
# Enter Sentence:  I am ravishankar kumar from india
# Total Words: 6
# I
# am
# ravishankar
# kumar
# from
# india
