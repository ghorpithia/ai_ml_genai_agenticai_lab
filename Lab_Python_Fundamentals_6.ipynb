# %%
etup=()
print(etup)
print(type(etup))
# Out:
# ()
# <class 'tuple'>

# %%
etup1=tuple()
print(etup1)
print(type(etup1))
# Out:
# ()
# <class 'tuple'>

# %%
tup1=("Elephant",4,642.6,"Horse")
print(tup1)
print(type(tup1))
# Out:
# ('Elephant', 4, 642.6, 'Horse')
# <class 'tuple'>

# %%
tup2=(100,200,300,400)
print(tup2)
print(type(tup2))
# Out:
# (100, 200, 300, 400)
# <class 'tuple'>

# %%
tup3=(100)
print(tup3)
print(type(tup3))
# Out:
# 100
# <class 'int'>

# %%
tup4=(100,)
print(tup4)
print(type(tup4))
# Out:
# (100,)
# <class 'tuple'>

# %%
tup5=100,
print(tup5)
print(type(tup5))
# Out:
# (100,)
# <class 'tuple'>

# %%
tup6=(100,200,"Orange",12.5,"Mango",100)
print(tup6)
print(type(tup6))
print(len(tup6))
# Out:
# (100, 200, 'Orange', 12.5, 'Mango', 100)
# <class 'tuple'>
# 6

# %%
tup6
# Out:
# (100, 200, 'Orange', 12.5, 'Mango', 100)

# %%
del tup6[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 del tup6[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
for i in tup6:
 print(i)
# Out:
# 100
# 200
# Orange
# 12.5
# Mango
# 100

# %%
tup6[3]
# Out:
# 12.5

# %%
tup6[5]
# Out:
# 100

# %%
tup6[1:4:1]
# Out:
# (200, 'Orange', 12.5)

# %%
tup6[2:8:1]
# Out:
# ('Orange', 12.5, 'Mango', 100)

# %%
eset=set()
print(eset)
print(type(eset))
# Out:
# set()
# <class 'set'>

# %%
s={"Laptop",12.5,"Watch",120,"Mobile"}
print(s)
print(type(s))
# Out:
# {'Watch', 'Mobile', 120, 12.5, 'Laptop'}
# <class 'set'>

# %%
s[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 s[1]
#
# TypeError: 'set' object is not subscriptable

# %%
s[1:4:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s[1:4:1]
#
# TypeError: 'set' object is not subscriptable

# %%
s={"Laptop",12.5,{100,200},"Watch",120,"Mobile"}
print(s)
print(type(s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s={"Laptop",12.5,{100,200},"Watch",120,"Mobile"}
#       2 print(s)
#       3 print(type(s))
#
# TypeError: unhashable type: 'set'

# %%
s.add(0.25)

# %%
s
# Out:
# {0.25, 12.5, 120, 'Laptop', 'Mobile', 'Watch'}

# %%
s.remove(12.5)

# %%
s
# Out:
# {0.25, 120, 'Laptop', 'Mobile', 'Watch'}

# %%
print("Hi all very good morning")
print("Welcome to python function")
print("We are doing python class")
print("Thanks for attending class")
# Out:
# Hi all very good morning
# Welcome to python function
# We are doing python class
# Thanks for attending class

# %%
print("Hi all very good morning")
print("************************")
for i in range(1,10):
    print(i)
print("Welcome to python function")
print("************************")
for i in range(1,10):
    print(i)
print("We are doing python class")
print("************************")
for i in range(1,10):
    print(i)
print("Thanks for attending class")
print("************************")
for i in range(1,10):
    print(i)
print("******Jai-Shree-Ram******")
# Out:
# Hi all very good morning
# ************************
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Welcome to python function
# ************************
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# We are doing python class
# ************************
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Thanks for attending class
# ************************
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# ******Jai-Shree-Ram******

# %%
def add_fun():
    print("Addition-Function")
    n1=int(input("enter first number"))
    n2=int(input("enter second number"))
    a=n1+n2
    print("Addition:",a)
add_fun()
print("**********")
add_fun()
print("**********")
add_fun()
print("**********")
# Out:
# Addition-Function
# enter first number 10
# enter second number 10
# Addition: 20
# **********
# Addition-Function
# enter first number 10
# enter second number 10
# Addition: 20
# **********
# Addition-Function
# enter first number 10
# enter second number 10
# Addition: 20
# **********

# %%
def add_fun():
    print("Addition-Function")
    n1=int(input("enter first number"))
    n2=int(input("enter second number"))
    n=n1+n2
    print("Addition:",n)
def mul_fun():
    print("Multiplication-Function")
    m1=int(input("enter first number"))
    m2=int(input("enter second number"))
    m=m1*m2
    print("Multiplication:",m)
add_fun()
print("**********")
mul_fun()
print("**********")
# Out:
# Addition-Function
# enter first number 10
# enter second number 10
# Addition: 20
# **********
# Multiplication-Function
# enter first number 10
# enter second number 10
# Multiplication: 100
# **********

# %%
res=lambda x:x+1000
print(res)
print(res(500))
# Out:
# <function <lambda> at 0x00000211204B3380>
# 1500

# %%
res1=lambda a,b:a+b
print(res1(100,200))
# Out:
# 300

# %%
res2=lambda c:c**3
print(res2(2))
# Out:
# 8

# %%
res3=lambda n1,n2:n1 if n1>=n2 else n2
res3(132,174)
# Out:
# 174

# %%
res4=lambda :"Welcome to lambda Function"
print(res4())
# Out:
# Welcome to lambda Function
