# %%
# Dictionary

# %%
list1= [10,20,44,120,33,35]
list2=[22,42,76,12,8,21]

# %%
print (list1),print (list2)
# Out:
# [10, 20, 44, 120, 33, 35]
# [22, 42, 76, 12, 8, 21]
# (None, None)

# %%
list1+list2
# Out:
# [10, 20, 44, 120, 33, 35, 22, 42, 76, 12, 8, 21]

# %%
for i in range(6) :
 print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(6) :
 print(list1[i]),print(list2[i])
 res=list1[i]+list2[i]
print(res)
# Out:
# 10
# 22
# 20
# 42
# 44
# 76
# 120
# 12
# 33
# 8
# 35
# 21
# 56

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d1=dict()
print(d1)
print(type(d1))
# Out:
# {}
# <class 'dict'>

# %%
d2 = {
    "I": "INDIA",
    "SKY": "BLUE",
    "2": "TWO",
    "B": "BHARAT"
}

print(d2)
print(type(d2))
len(d2)
d2.keys(),d2.values(),d2.items()
# Out:
# {'I': 'INDIA', 'SKY': 'BLUE', '2': 'TWO', 'B': 'BHARAT'}
# <class 'dict'>
# (dict_keys(['I', 'SKY', '2', 'B']),
#  dict_values(['INDIA', 'BLUE', 'TWO', 'BHARAT']),
#  dict_items([('I', 'INDIA'), ('SKY', 'BLUE'), ('2', 'TWO'), ('B', 'BHARAT')]))

# %%
d3=dict([("A","APPLE"),("K","KING"),("Q","Queen"),("Z","ZEBRA")])

# %%
print(d3)
# Out:
# {'A': 'APPLE', 'K': 'KING', 'Q': 'Queen', 'Z': 'ZEBRA'}

# %%
d3["K"]
# Out:
# 'KING'

# %%
d3["Z"]
# Out:
# 'ZEBRA'

# %%
d3["Q"]
# Out:
# 'Queen'

# %%
d3.get("A")
# Out:
# 'APPLE'

# %%
d3.get("K")
# Out:
# 'KING'

# %%
d3.get("P")

# %%
d3.get("P","NO Such Key")
# Out:
# 'NO Such Key'

# %%
import time
d3
{'A':'APPLE','K':'KING','Q':'QUENN','z':'ZEBRA'}
for x in d3:
    print(x)
    time.sleep(5)
# Out:
# A
# K
# Q
# Z

# %%
for x in d3.keys():
    print(x)
# Out:
# A
# K
# Q
# Z

# %%
for v in d3.values():
    print(v)
# Out:
# APPLE
# KING
# Queen
# ZEBRA

# %%
for i in d3.items():
    print(i)
# Out:
# ('A', 'APPLE')
# ('K', 'KING')
# ('Q', 'Queen')
# ('Z', 'ZEBRA')

# %%
for k,v in d3.items():
    print(k),print(v)
# Out:
# A
# APPLE
# K
# KING
# Q
# Queen
# Z
# ZEBRA

# %%
d3
{'A':'APPLE','K':'KING','Q':'QUEEN','Z':'ZEBRA'}
d3["K"]
d3["R"]="ROYAL"
d3["K"]="KITE"
d3
# Out:
# {'A': 'APPLE', 'K': 'KITE', 'Q': 'Queen', 'Z': 'ZEBRA', 'R': 'ROYAL'}

# %%
d3.pop("A")
# Out:
# 'APPLE'

# %%
d3
# Out:
# {'K': 'KITE', 'Q': 'Queen', 'Z': 'ZEBRA', 'R': 'ROYAL'}

# %%
print(d3)
# Out:
# {'K': 'KITE', 'Q': 'Queen', 'Z': 'ZEBRA', 'R': 'ROYAL'}

# %%
d3.clear
# Out:
# <function dict.clear()>

# %%
d3.update([(1,111),(2,222),(3,333),(4,444)])

# %%
d3
# Out:
# {'K': 'KITE',
#  'Q': 'Queen',
#  'Z': 'ZEBRA',
#  'R': 'ROYAL',
#  1: 111,
#  2: 222,
#  3: 333,
#  4: 444}

# %%
# Tuple

# %%
etup=()
print(etup)
print(type(etup))
# Out:
# ()
# <class 'tuple'>

# %%
tup=("Elephant",4,642.6,"Horse")
print(tup)
print(type)
# Out:
# ('Elephant', 4, 642.6, 'Horse')
# <class 'type'>

# %%
tup1=(100,200,"Orange",12.5,"mango",100)
print(tup1)
print(type(tup1))
print(len(tup1))
# Out:
# (100, 200, 'Orange', 12.5, 'mango', 100)
# <class 'tuple'>
# 6

# %%
tup1
(100,200,"Orange",12.5,"mango",100)
del tup1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 3
#       1 tup1
#       2 (100,200,"Orange",12.5,"mango",100)
# ----> 3 del tup1[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
for i in tup1:
    print(i)
# Out:
# 100
# 200
# Orange
# 12.5
# mango
# 100

# %%
tup1[1]
# Out:
# 200

# %%
tup1[2]
# Out:
# 'Orange'

# %%
 tup1[1:4:1]
# Out:
# (200, 'Orange', 12.5)

# %%
# Set

# %%
eset=set()
print(eset)
print(type(eset))
# Out:
# set()
# <class 'set'>
